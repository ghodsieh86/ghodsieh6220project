# %% [markdown]
# <a href="https://colab.research.google.com/github/ghodsieh86/ghodsieh6220project/blob/main/Copy_of_parkinson_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #install pycaret

# %%
# !pip install pycaret==2.3.6
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycaret==2.3.6 in /usr/local/lib/python3.9/dist-packages (2.3.6)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (3.3.1)
# Requirement already satisfied: pandas-profiling>=2.8.0 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (3.6.6)
# Requirement already satisfied: yellowbrick>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (1.2.1)
# Requirement already satisfied: Boruta in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (0.3)
# Requirement already satisfied: spacy<2.4.0 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (2.3.9)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (1.8.2.2)
# Requirement already satisfied: scipy<=1.5.4 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (1.5.4)
# Requirement already satisfied: IPython in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (7.34.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (1.5.3)
# Requirement already satisfied: imbalanced-learn==0.7.0 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (0.7.0)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (0.5.3)
# Requirement already satisfied: textblob in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (0.17.1)
# Requirement already satisfied: kmodes>=0.10.1 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (0.12.2)
# Requirement already satisfied: gensim<4.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (3.8.3)
# Requirement already satisfied: mlxtend>=0.17.0 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (0.19.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (3.6.3)
# Requirement already satisfied: pyod in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (1.0.9)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (3.3.5)
# Requirement already satisfied: plotly>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (5.13.1)
# Requirement already satisfied: mlflow in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (2.3.0)
# Requirement already satisfied: cufflinks>=0.17.0 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (0.17.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (1.2.0)
# Requirement already satisfied: scikit-learn==0.23.2 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (0.23.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (7.7.1)
# Requirement already satisfied: scikit-plot in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (0.3.7)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (3.8.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (0.12.2)
# Requirement already satisfied: pyyaml<6.0.0 in /usr/local/lib/python3.9/dist-packages (from pycaret==2.3.6) (5.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/dist-packages (from imbalanced-learn==0.7.0->pycaret==2.3.6) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==0.23.2->pycaret==2.3.6) (3.1.0)
# Requirement already satisfied: colorlover>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from cufflinks>=0.17.0->pycaret==2.3.6) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from cufflinks>=0.17.0->pycaret==2.3.6) (1.16.0)
# Requirement already satisfied: setuptools>=34.4.1 in /usr/local/lib/python3.9/dist-packages (from cufflinks>=0.17.0->pycaret==2.3.6) (67.7.2)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim<4.0.0->pycaret==2.3.6) (6.3.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from IPython->pycaret==2.3.6) (5.7.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.9/dist-packages (from IPython->pycaret==2.3.6) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from IPython->pycaret==2.3.6) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from IPython->pycaret==2.3.6) (3.0.38)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from IPython->pycaret==2.3.6) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from IPython->pycaret==2.3.6) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from IPython->pycaret==2.3.6) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from IPython->pycaret==2.3.6) (0.1.6)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from IPython->pycaret==2.3.6) (2.14.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->pycaret==2.3.6) (3.0.7)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->pycaret==2.3.6) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->pycaret==2.3.6) (5.5.6)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->pycaret==2.3.6) (3.6.4)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm>=2.3.1->pycaret==2.3.6) (0.40.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pycaret==2.3.6) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pycaret==2.3.6) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pycaret==2.3.6) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pycaret==2.3.6) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pycaret==2.3.6) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pycaret==2.3.6) (23.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pycaret==2.3.6) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pycaret==2.3.6) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pycaret==2.3.6) (2022.7.1)
# Requirement already satisfied: ydata-profiling in /usr/local/lib/python3.9/dist-packages (from pandas-profiling>=2.8.0->pycaret==2.3.6) (4.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.4.1->pycaret==2.3.6) (8.2.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (1.0.9)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (1.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (3.0.8)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (7.4.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (0.7.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (2.27.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<2.4.0->pycaret==2.3.6) (4.64.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (3.20.3)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (3.1.31)
# Requirement already satisfied: docker<7,>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (6.0.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (6.6.0)
# Requirement already satisfied: pyarrow<12,>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (9.0.0)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (2.2.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (1.10.4)
# Requirement already satisfied: gunicorn<21 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (20.1.0)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (0.4)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (3.1.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (2.0.10)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (0.4.4)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (8.1.3)
# Requirement already satisfied: querystring-parser<2 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (1.2.4)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (3.4.3)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (0.17.6)
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.9/dist-packages (from mlflow->pycaret==2.3.6) (2.2.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk->pycaret==2.3.6) (2022.10.31)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.9/dist-packages (from pyLDAvis->pycaret==2.3.6) (0.0.post4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.9/dist-packages (from pyLDAvis->pycaret==2.3.6) (2.8.4)
# Requirement already satisfied: funcy in /usr/local/lib/python3.9/dist-packages (from pyLDAvis->pycaret==2.3.6) (2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from pyLDAvis->pycaret==2.3.6) (0.18.3)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.9/dist-packages (from pyod->pycaret==2.3.6) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.9/dist-packages (from umap-learn->pycaret==2.3.6) (0.5.10)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic!=1.10.0,<2->mlflow->pycaret==2.3.6) (4.5.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.9/dist-packages (from alembic!=1.10.0,<2->mlflow->pycaret==2.3.6) (1.2.4)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret==2.3.6) (2.6.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret==2.3.6) (0.8.10)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret==2.3.6) (3.2.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.9/dist-packages (from docker<7,>=4.0.0->mlflow->pycaret==2.3.6) (1.26.15)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.9/dist-packages (from docker<7,>=4.0.0->mlflow->pycaret==2.3.6) (1.5.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask<3->mlflow->pycaret==2.3.6) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask<3->mlflow->pycaret==2.3.6) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from gitpython<4,>=2.1.0->mlflow->pycaret==2.3.6) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow->pycaret==2.3.6) (3.15.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.3.6) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.3.6) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->IPython->pycaret==2.3.6) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2<4,>=2.11->mlflow->pycaret==2.3.6) (2.1.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.51->pyod->pycaret==2.3.6) (0.39.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->IPython->pycaret==2.3.6) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret==2.3.6) (0.2.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.6) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.6) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.6) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow->pycaret==2.3.6) (2.0.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (6.4.8)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (1.10.7)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (4.3.1)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (0.13.5)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (0.1.12)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (0.7.5)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (2.13.3)
# Requirement already satisfied: multimethod<1.10,>=1.4 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (1.9.1)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (0.12.3)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.9/dist-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (1.4.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (0.2.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (3.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.9/dist-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (23.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->pycaret==2.3.6) (5.0.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (5.3.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (6.5.4)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (21.3.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (0.16.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (1.5.6)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (0.17.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (5.8.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (1.8.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling>=2.8.0->pycaret==2.3.6) (0.5.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (3.2.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (21.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (4.11.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (0.7.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (6.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (0.2.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (1.5.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (4.9.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.6) (2.21)

# %%
#Run the below code in your notebook to check the installed version
from pycaret.utils import version
version()
# Out:
# '2.3.6'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
from google.colab import files
plt.rcParams['figure.figsize'] = (7,5)
import gdown

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
print("Pandas version: ", pd.__version__)
print("Seaborn version: ", sns.__version__)
# Out:
# Pandas version:  1.5.3
# Seaborn version:  0.12.2

# %%
#read csv file into dataframe
df = pd.read_csv('')
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-82-630eb968cf1d> in <cell line: 2>()
#       1 #read csv file into dataframe
# ----> 2 df = pd.read_csv('')
#       3 df.head(10)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
#read csv file into dataframe
df = pd.read_csv('/content/drive/MyDrive/dataset/parkinson-disease.csv')
df.head(10)
# Out:
#    Flo(Hz)  Jitter(%)  Jitter(Abs)      RAP      PPQ  Jitter:DDP  \
# 0   74.997    0.00784      0.00007  0.00370  0.00554     0.01109
# 1  113.819    0.00968      0.00008  0.00465  0.00696     0.01394
# 2  111.555    0.01050      0.00009  0.00544  0.00781     0.01633
# 3  111.366    0.00997      0.00009  0.00502  0.00698     0.01505
# 4  110.655    0.01284      0.00011  0.00655  0.00908     0.01966
# 5  113.787    0.00968      0.00008  0.00463  0.00750     0.01388
# 6  114.820    0.00333      0.00003  0.00155  0.00202     0.00466
# 7  104.315    0.00290      0.00003  0.00144  0.00182     0.00431
# 8   91.754    0.00551      0.00006  0.00293  0.00332     0.00880
# 9   91.226    0.00532      0.00006  0.00268  0.00332     0.00803
#
#    MDVP:Shimmer  status
# 0       0.04374       1
# 1       0.06134       1
# 2       0.05233       1
# 3       0.05492       1
# 4       0.06425       1
# 5       0.04701       1
# 6       0.01608       1
# 7       0.01567       1
# 8       0.02093       1
# 9       0.02838       1

# %%
#read csv file into dataframe
df = pd.read_csv('/content/drive/MyDrive/dataset/parkinson-disease.csv')
df.head(10)
# Out:
#    Flo(Hz)  Jitter(%)  Jitter(Abs)      RAP      PPQ  Jitter:DDP  \
# 0   74.997    0.00784      0.00007  0.00370  0.00554     0.01109
# 1  113.819    0.00968      0.00008  0.00465  0.00696     0.01394
# 2  111.555    0.01050      0.00009  0.00544  0.00781     0.01633
# 3  111.366    0.00997      0.00009  0.00502  0.00698     0.01505
# 4  110.655    0.01284      0.00011  0.00655  0.00908     0.01966
# 5  113.787    0.00968      0.00008  0.00463  0.00750     0.01388
# 6  114.820    0.00333      0.00003  0.00155  0.00202     0.00466
# 7  104.315    0.00290      0.00003  0.00144  0.00182     0.00431
# 8   91.754    0.00551      0.00006  0.00293  0.00332     0.00880
# 9   91.226    0.00532      0.00006  0.00268  0.00332     0.00803
#
#    MDVP:Shimmer  status
# 0       0.04374       1
# 1       0.06134       1
# 2       0.05233       1
# 3       0.05492       1
# 4       0.06425       1
# 5       0.04701       1
# 6       0.01608       1
# 7       0.01567       1
# 8       0.02093       1
# 9       0.02838       1

# %%
#read csv file into dataframe
df = pd.read_csv('/content/drive/MyDrive/dataset/parkinson-disease.csv')
df.head(10)
# Out:
#    Flo(Hz)  Jitter(%)  Jitter(Abs)      RAP      PPQ  Jitter:DDP  \
# 0   74.997    0.00784      0.00007  0.00370  0.00554     0.01109
# 1  113.819    0.00968      0.00008  0.00465  0.00696     0.01394
# 2  111.555    0.01050      0.00009  0.00544  0.00781     0.01633
# 3  111.366    0.00997      0.00009  0.00502  0.00698     0.01505
# 4  110.655    0.01284      0.00011  0.00655  0.00908     0.01966
# 5  113.787    0.00968      0.00008  0.00463  0.00750     0.01388
# 6  114.820    0.00333      0.00003  0.00155  0.00202     0.00466
# 7  104.315    0.00290      0.00003  0.00144  0.00182     0.00431
# 8   91.754    0.00551      0.00006  0.00293  0.00332     0.00880
# 9   91.226    0.00532      0.00006  0.00268  0.00332     0.00803
#
#    MDVP:Shimmer  status
# 0       0.04374       1
# 1       0.06134       1
# 2       0.05233       1
# 3       0.05492       1
# 4       0.06425       1
# 5       0.04701       1
# 6       0.01608       1
# 7       0.01567       1
# 8       0.02093       1
# 9       0.02838       1

# %%
#read csv file into dataframe
df = pd.read_csv('/content/drive/MyDrive/dataset/parkinson-disease.csv')
df.head(10)
# Out:
#    Flo(Hz)  Jitter(%)  Jitter(Abs)      RAP      PPQ  Jitter:DDP  \
# 0   74.997    0.00784      0.00007  0.00370  0.00554     0.01109
# 1  113.819    0.00968      0.00008  0.00465  0.00696     0.01394
# 2  111.555    0.01050      0.00009  0.00544  0.00781     0.01633
# 3  111.366    0.00997      0.00009  0.00502  0.00698     0.01505
# 4  110.655    0.01284      0.00011  0.00655  0.00908     0.01966
# 5  113.787    0.00968      0.00008  0.00463  0.00750     0.01388
# 6  114.820    0.00333      0.00003  0.00155  0.00202     0.00466
# 7  104.315    0.00290      0.00003  0.00144  0.00182     0.00431
# 8   91.754    0.00551      0.00006  0.00293  0.00332     0.00880
# 9   91.226    0.00532      0.00006  0.00268  0.00332     0.00803
#
#    MDVP:Shimmer  status
# 0       0.04374       1
# 1       0.06134       1
# 2       0.05233       1
# 3       0.05492       1
# 4       0.06425       1
# 5       0.04701       1
# 6       0.01608       1
# 7       0.01567       1
# 8       0.02093       1
# 9       0.02838       1

# %%
#read csv file into dataframe
df = pd.read_csv('/content/drive/MyDrive/dataset/parkinson-disease.csv')
df.head(10)
# Out:
#    Flo(Hz)  Jitter(%)  Jitter(Abs)      RAP      PPQ  Jitter:DDP  \
# 0   74.997    0.00784      0.00007  0.00370  0.00554     0.01109
# 1  113.819    0.00968      0.00008  0.00465  0.00696     0.01394
# 2  111.555    0.01050      0.00009  0.00544  0.00781     0.01633
# 3  111.366    0.00997      0.00009  0.00502  0.00698     0.01505
# 4  110.655    0.01284      0.00011  0.00655  0.00908     0.01966
# 5  113.787    0.00968      0.00008  0.00463  0.00750     0.01388
# 6  114.820    0.00333      0.00003  0.00155  0.00202     0.00466
# 7  104.315    0.00290      0.00003  0.00144  0.00182     0.00431
# 8   91.754    0.00551      0.00006  0.00293  0.00332     0.00880
# 9   91.226    0.00532      0.00006  0.00268  0.00332     0.00803
#
#    MDVP:Shimmer  status
# 0       0.04374       1
# 1       0.06134       1
# 2       0.05233       1
# 3       0.05492       1
# 4       0.06425       1
# 5       0.04701       1
# 6       0.01608       1
# 7       0.01567       1
# 8       0.02093       1
# 9       0.02838       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Flo(Hz)       195 non-null    float64
#  1   Jitter(%)     195 non-null    float64
#  2   Jitter(Abs)   195 non-null    float64
#  3   RAP           195 non-null    float64
#  4   PPQ           195 non-null    float64
#  5   Jitter:DDP    195 non-null    float64
#  6   MDVP:Shimmer  195 non-null    float64
#  7   status        195 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 12.3 KB

# %%
print("Number of rows with NaNs is: ", df.isna().any(axis=1).sum())
# Out:
# Number of rows with NaNs is:  0

# %% [markdown]
# Explaratory data analysis

# %%
sns.pairplot(df,hue="status")
plt.show()

# %%
y=df['status']
y.value_counts().plot(kind='pie')
plt.ylabel('')
plt.show()

# %% [markdown]
# data matrix

# %%
X = df.drop(columns=['status'])
X.head(10)
# Out:
#    Flo(Hz)  Jitter(%)  Jitter(Abs)      RAP      PPQ  Jitter:DDP  MDVP:Shimmer
# 0   74.997    0.00784      0.00007  0.00370  0.00554     0.01109       0.04374
# 1  113.819    0.00968      0.00008  0.00465  0.00696     0.01394       0.06134
# 2  111.555    0.01050      0.00009  0.00544  0.00781     0.01633       0.05233
# 3  111.366    0.00997      0.00009  0.00502  0.00698     0.01505       0.05492
# 4  110.655    0.01284      0.00011  0.00655  0.00908     0.01966       0.06425
# 5  113.787    0.00968      0.00008  0.00463  0.00750     0.01388       0.04701
# 6  114.820    0.00333      0.00003  0.00155  0.00202     0.00466       0.01608
# 7  104.315    0.00290      0.00003  0.00144  0.00182     0.00431       0.01567
# 8   91.754    0.00551      0.00006  0.00293  0.00332     0.00880       0.02093
# 9   91.226    0.00532      0.00006  0.00268  0.00332     0.00803       0.02838

# %%
X.describe().transpose()
# Out:
#               count        mean        std        min        25%        50%  \
# Flo(Hz)       195.0  116.324631  43.521413  65.476000  84.291000  104.31500
# Jitter(%)     195.0    0.006220   0.004848   0.001680   0.003460    0.00494
# Jitter(Abs)   195.0    0.000044   0.000035   0.000007   0.000020    0.00003
# RAP           195.0    0.003306   0.002968   0.000680   0.001660    0.00250
# PPQ           195.0    0.003446   0.002759   0.000920   0.001860    0.00269
# Jitter:DDP    195.0    0.009920   0.008903   0.002040   0.004985    0.00749
# MDVP:Shimmer  195.0    0.029709   0.018857   0.009540   0.016505    0.02297
#
#                      75%        max
# Flo(Hz)       140.018500  239.17000
# Jitter(%)       0.007365    0.03316
# Jitter(Abs)     0.000060    0.00026
# RAP             0.003835    0.02144
# PPQ             0.003955    0.01958
# Jitter:DDP      0.011505    0.06433
# MDVP:Shimmer    0.037885    0.11908

# %% [markdown]
# Data standardization

# %%
Xs = StandardScaler().fit_transform(X)
Xcols = X.columns
X = pd.DataFrame(Xs)
X.columns = Xcols
X.head(10)
# Out:
#     Flo(Hz)  Jitter(%)  Jitter(Abs)       RAP       PPQ  Jitter:DDP  \
# 0 -0.952037   0.334914     0.749759  0.132963  0.760800    0.131755
# 1 -0.057721   0.715418     1.037674  0.453892  1.276809    0.452684
# 2 -0.109875   0.884991     1.325589  0.720770  1.585687    0.721813
# 3 -0.114229   0.775389     1.325589  0.578885  1.284076    0.577677
# 4 -0.130608   1.368893     1.901418  1.095750  2.047187    1.096793
# 5 -0.058458   0.715418     1.037674  0.447135  1.473037    0.445927
# 6 -0.034661  -0.597735    -0.401899 -0.593351 -0.518319   -0.592304
# 7 -0.276658  -0.686658    -0.401899 -0.630511 -0.590996   -0.631716
# 8 -0.566017  -0.146921     0.461845 -0.127159 -0.045917   -0.126113
# 9 -0.578181  -0.186212     0.461845 -0.211614 -0.045917   -0.212820
#
#    MDVP:Shimmer
# 0      0.745985
# 1      1.681731
# 2      1.202693
# 3      1.340396
# 4      1.836448
# 5      0.919842
# 6     -0.724625
# 7     -0.746424
# 8     -0.466763
# 9     -0.070666

# %% [markdown]
# obsevation and variables

# %%
observations = list(df.index)
variables = list(df.columns)

# %% [markdown]
# box and whisker plots

# %%
ax = plt.figure()
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %%
ax = plt.figure()    
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax = sns.stripplot(data=X, color=".25") 
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# correlation matrix

# %%
ax = sns.heatmap(X.corr(), cmap='RdYlGn_r', linewidths=0.5, annot=True, cbar=False, square=True)
plt.yticks(rotation=0)
ax.tick_params(labelbottom=False,labeltop=True)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# PCA

# %%
pca = PCA()
Z = pca.fit_transform(X)

# 1(Healthy)->0,  2(PD)->1, 
idx_Healthy = np.where(y == 0)
idx_PD = np.where(y == 1)

plt. figure()
plt.scatter(Z[idx_Healthy,0], Z[idx_Healthy,1], c='r', label='Healthy')
plt.scatter(Z[idx_PD,0], Z[idx_PD,1], c='g', label='PD')
plt.legend()
plt.xlabel('$Z_1$')
plt.ylabel('$Z_2$')
# Out:
# Text(0, 0.5, '$Z_2$')

# %% [markdown]
# eigenvectors

# %%
A = pca.components_.T 
plt.scatter(A[:,0],A[:,1],c='r')
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for label, x, y in zip(variables, A[:, 0], A[:, 1]):
  plt.annotate(label, xy=(x, y), xytext=(-2, 2), textcoords='offset points', ha='right', va='bottom')

# %%
plt.scatter(A[:, 0],A[:, 1], marker='o', c=A[:, 2], s=A[:, 3]*500, cmap=plt.get_cmap('Spectral'))

plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for label, x, y in zip(variables,A[:, 0],A[:, 1]):
  plt.annotate(label,xy=(x, y), xytext=(-20, 20),
      textcoords='offset points', ha='right', va='bottom',
      bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
      arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

# %% [markdown]
# Scree plot

# %%
#Eigenvalues
Lambda = pca.explained_variance_ 

#Scree plot
x = np.arange(len(Lambda)) + 1
plt.plot(x,Lambda/sum(Lambda), 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
# Out:
# Text(0, 0.5, 'Explained variance')

# %% [markdown]
# explained variance

# %%
ell = pca.explained_variance_ratio_
ind = np.arange(len(ell))
plt.bar(ind, ell, align='center', alpha=0.5)
plt.plot(np.cumsum(ell))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %% [markdown]
# biplot

# %%
# 0,1 denote PC1 and PC2; change values for other PCs
A1 = A[:,0] 
A2 = A[:,1]
Z1 = Z[:,0] 
Z2 = Z[:,1]

plt.figure()
plt.xlabel('$Z_1$')
plt.ylabel('$Z_2$')
for i in range(len(A1)):
# arrows project features as vectors onto PC axes
  plt.arrow(0, 0, A1[i]*max(Z1), A2[i]*max(Z2), color='k', width=0.0005, head_width=0.0025)
  plt.text(A1[i]*max(Z1)*1.2, A2[i]*max(Z2)*1.2,variables[i], color='k')

plt.scatter(Z[idx_Healthy,0], Z[idx_Healthy,1], c='r', label='Healthy')
plt.scatter(Z[idx_PD,0], Z[idx_PD,1], c='g', label='PD')
plt.legend(loc='upper left')

# %%
# !pip install pca
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pca in /usr/local/lib/python3.9/dist-packages (2.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from pca) (2.27.1)
# Requirement already satisfied: scatterd>=1.3.1 in /usr/local/lib/python3.9/dist-packages (from pca) (1.3.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from pca) (0.23.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from pca) (3.6.3)
# Requirement already satisfied: colourmap>=1.1.11 in /usr/local/lib/python3.9/dist-packages (from pca) (1.1.11)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.9/dist-packages (from pca) (0.13.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from pca) (4.64.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from pca) (1.5.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from pca) (1.5.3)
# Requirement already satisfied: adjusttext in /usr/local/lib/python3.9/dist-packages (from pca) (0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pca) (1.22.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from scatterd>=1.3.1->pca) (0.12.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pca) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pca) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pca) (4.39.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pca) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pca) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pca) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pca) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pca) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pca) (2022.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->pca) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->pca) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->pca) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->pca) (2.0.12)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->pca) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->pca) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels->pca) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels->pca) (1.16.0)

# %%
from pca import pca
# Initialize and keep all PCs
model = pca()
# Fit transform
out = model.fit_transform(X)
# Out:
# [pca] >Extracting column labels from dataframe.
# [pca] >Extracting row labels from dataframe.
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [7] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [3] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [7] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[3]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]

# %% [markdown]
# Principal components

# %%
out['PC']
# Out:
#           PC1       PC2       PC3
# 0    1.210384 -0.919886  0.374321
# 1    2.234514  0.040189  0.978566
# 2    2.610717  0.030316  0.338137
# 3    2.367772 -0.027632  0.534368
# 4    3.781406  0.065245  0.553460
# ..        ...       ...       ...
# 190 -0.376667 -0.526463  0.788859
# 191 -0.285019 -0.579785  0.023005
# 192  2.179757 -0.779644 -1.191831
# 193  0.183517 -0.877427 -0.382651
# 194 -0.490057 -0.853977 -0.359854
#
# [195 rows x 3 columns]

# %% [markdown]
# scatter plot

# %%
model.scatter(label=True, legend=False)
# Out:
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '3 Principal Components explain [99.17%] of the variance'}, xlabel='PC1 (78.4% expl.var)', ylabel='PC2 (14.3% expl.var)'>)

# %% [markdown]
# eigenvectors

# %%
A = out['loadings'].T

# %%
sns.scatterplot(data=A, x="PC1", y="PC2")
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for i in range(A.shape[0]):
 plt.text(x=A.PC1[i]+0.02,y=A.PC2[i]+0.03, s=variables[i],
          fontdict=dict(color='red',size=9),
          bbox=dict(facecolor='yellow',alpha=0.5))

# %% [markdown]
# scree plot

# %%
VR = out['variance_ratio']
x = np.arange(len(VR)) + 1
plt.plot(x, VR, 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance') 
plt.show()

# %% [markdown]
# explained variance plot

# %%
model.plot();

# %% [markdown]
# biplot

# %%
model.biplot(label=False, legend=False)
# Out:
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '3 Principal Components explain [99.17%] of the variance'}, xlabel='PC1 (78.4% expl.var)', ylabel='PC2 (14.3% expl.var)'>)

# %%
model.biplot3d(label = False, legend=False)
# Out:
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 vs PC3 with loadings.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes3D: title={'center': '3 Principal Components explain [99.17%] of the variance'}, xlabel='PC1 (78.4% expl.var)', ylabel='PC2 (14.3% expl.var)', zlabel='PC3 (5.23% expl.var)'>)

# %% [markdown]
# classification

# %%
#For Google Colab only
# !pip install scikit-learn==0.23.2
# from pycaret.utils import enable_colab 
# enable_colab()

# %%
data = df.sample(frac=0.9, random_state=786)
data_unseen = df.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (176, 8)
# Unseen Data For Predictions: (19, 8)

# %%
from pycaret.classification import *
clf = setup(data=data, target='status', train_size=0.7, session_id=123)
# Out:
#                                Description             Value
# 0                               session_id               123
# 1                                   Target            status
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data          (176, 8)
# 5                           Missing Values             False
# 6                         Numeric Features                 7
# 7                     Categorical Features                 0
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set          (123, 6)
# 12                    Transformed Test Set           (53, 6)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              7456
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE
# INFO:logs:create_model_container: 0
# INFO:logs:master_model_container: 0
# INFO:logs:display_container: 1
# INFO:logs:Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='status',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strat...
#                 ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                 ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                 ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='status')),
#                 ('fix_perfect', Remove_100(target='status')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# INFO:logs:setup() succesfully completed......................................

# %% [markdown]
# Models comparison

# %%
 #show the best model and their statistics
 best_model = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.9019  0.9415  0.9778  0.9049
# rf               Random Forest Classifier    0.8782  0.8578  0.9456  0.9078
# gbc          Gradient Boosting Classifier    0.8782  0.9126  0.9467  0.9045
# lightgbm  Light Gradient Boosting Machine    0.8776  0.8689  0.9456  0.9106
# ada                  Ada Boost Classifier    0.8551  0.9044  0.9256  0.8947
# xgboost         Extreme Gradient Boosting    0.8545  0.8700  0.9367  0.8905
# dt               Decision Tree Classifier    0.8462  0.7744  0.9156  0.8964
# ridge                    Ridge Classifier    0.8295  0.0000  0.9789  0.8324
# lr                    Logistic Regression    0.8218  0.7241  0.9689  0.8324
# lda          Linear Discriminant Analysis    0.7891  0.7696  0.9256  0.8257
# knn                K Neighbors Classifier    0.7737  0.7252  0.8944  0.8266
# dummy                    Dummy Classifier    0.7558  0.5000  1.0000  0.7558
# qda       Quadratic Discriminant Analysis    0.7231  0.8378  0.6878  0.9298
# nb                            Naive Bayes    0.6814  0.8348  0.6211  0.9342
# svm                   SVM - Linear Kernel    0.4981  0.0000  0.5000  0.3769
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.9387  0.6924  0.7191     0.359
# rf        0.9231  0.6161  0.6299     0.362
# gbc       0.9223  0.6353  0.6610     0.146
# lightgbm  0.9223  0.6099  0.6398     0.258
# ada       0.9069  0.5701  0.5969     0.175
# xgboost   0.9076  0.5464  0.5846     0.109
# dt        0.8986  0.5581  0.5994     0.014
# ridge     0.8982  0.3905  0.4216     0.013
# lr        0.8929  0.3711  0.4038     0.749
# lda       0.8690  0.3092  0.3366     0.028
# knn       0.8557  0.3079  0.3252     0.021
# dummy     0.8609  0.0000  0.0000     0.021
# qda       0.7890  0.4083  0.4525     0.026
# nb        0.7436  0.3650  0.4220     0.016
# svm       0.4298  0.0000  0.0000     0.016
# INFO:logs:create_model_container: 15
# INFO:logs:master_model_container: 15
# INFO:logs:display_container: 2
# INFO:logs:ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)
# INFO:logs:compare_models() succesfully completed......................................

# %%
best_model
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)

# %% [markdown]
# model creation

# %%
et = create_model('et')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8462  0.9333  1.0000  0.8333  0.9091  0.4348  0.5270
# 1       0.9231  1.0000  1.0000  0.9091  0.9524  0.7547  0.7785
# 2       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       0.9167  0.9630  1.0000  0.9000  0.9474  0.7500  0.7746
# 4       0.8333  0.8889  0.8889  0.8889  0.8889  0.5556  0.5556
# 5       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       0.9167  0.8519  1.0000  0.9000  0.9474  0.7500  0.7746
# 7       0.8333  0.9630  1.0000  0.8182  0.9000  0.4286  0.5222
# 8       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 9       0.7500  0.8148  0.8889  0.8000  0.8421  0.2500  0.2582
# Mean    0.9019  0.9415  0.9778  0.9049  0.9387  0.6924  0.7191
# SD      0.0808  0.0644  0.0444  0.0715  0.0508  0.2539  0.2369
# INFO:logs:create_model_container: 17
# INFO:logs:master_model_container: 17
# INFO:logs:display_container: 4
# INFO:logs:ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)
# INFO:logs:create_model() succesfully completed......................................

# %%
#trained model object is stored in the variable 'et'.
et
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)

# %% [markdown]
# model tuning

# %%
# !pip install scikit-optimize
# !pip install tune-sklearn ray[tune]
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.9/dist-packages (0.9.0)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize) (21.10.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize) (1.22.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize) (0.23.2)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.9/dist-packages (from scikit-optimize) (1.5.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from pyaml>=16.9->scikit-optimize) (5.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tune-sklearn in /usr/local/lib/python3.9/dist-packages (0.4.5)
# Requirement already satisfied: ray[tune] in /usr/local/lib/python3.9/dist-packages (2.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from tune-sklearn) (0.23.2)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.9/dist-packages (from tune-sklearn) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from tune-sklearn) (1.5.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (8.1.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (3.20.3)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (1.3.3)
# Requirement already satisfied: grpcio<=1.51.3,>=1.32.0 in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (1.51.3)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (1.3.1)
# Requirement already satisfied: virtualenv<20.21.1,>=20.0.24 in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (20.21.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (4.3.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (5.4.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (1.0.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (3.12.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (23.1.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (0.8.10)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (2.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from ray[tune]) (1.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorboardX>=1.9->ray[tune]) (23.1)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.9/dist-packages (from virtualenv<20.21.1,>=20.0.24->ray[tune]) (0.3.6)
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.9/dist-packages (from virtualenv<20.21.1,>=20.0.24->ray[tune]) (3.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->ray[tune]) (0.19.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ray[tune]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ray[tune]) (2022.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->ray[tune]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->ray[tune]) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->ray[tune]) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->ray[tune]) (1.26.15)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->tune-sklearn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->tune-sklearn) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->ray[tune]) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.9/dist-packages (3.1.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.9/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna) (5.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (23.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (1.10.4)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from optuna) (0.9.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)

# %% [markdown]
# extra tree model tuning

# %%
tuned_et = tune_model(et, search_library='tune-sklearn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-6bc58e5ed935> in <cell line: 1>()
# ----> 1 tuned_et = tune_model(et, search_library='tune-sklearn')
#
# /usr/local/lib/python3.9/dist-packages/pycaret/classification.py in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, **kwargs)
#    1099     """
#    1100
# -> 1101     return pycaret.internal.tabular.tune_model_supervised(
#    1102         estimator=estimator,
#    1103         fold=fold,
#
# /usr/local/lib/python3.9/dist-packages/pycaret/internal/tabular.py in tune_model_supervised(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, display, **kwargs)
#    4560                 model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4561         else:
# -> 4562             model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4563         best_params = model_grid.best_params_
#    4564         logger.info(f"best_params: {best_params}")
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_basesearch.py in fit(self, X, y, groups, tune_params, **fit_params)
#     619
#     620         """
# --> 621         return self._fit(X, y, groups, tune_params, **fit_params)
#     622
#     623     def score(self, X, y=None):
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_basesearch.py in _fit(self, X, y, groups, tune_params, **fit_params)
#     530
#     531         self._fill_config_hyperparam(config)
# --> 532         self.analysis_ = self._tune_run(X, y, config, resources_per_trial,
#     533                                         tune_params, fit_params)
#     534
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_search.py in _tune_run(self, X, y, config, resources_per_trial, tune_params, fit_params)
#     820                 "ignore", message="fail_fast='raise' "
#     821                 "detected.")
# --> 822             analysis = tune.run(trainable, **run_args)
#     823         return analysis
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, chdir_to_trial_dir, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, trial_executor, _experiment_checkpoint_dir, _remote, _remote_string_queue, _tuner_api)
#     902                 not runner.is_finished() and not experiment_interrupted_event.is_set()
#     903             ):
# --> 904                 runner.step()
#     905                 if has_verbosity(Verbosity.V1_EXPERIMENT):
#     906                     _report_progress(runner, progress_reporter)
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in step(self)
#    1336             )
#    1337
# -> 1338         next_trial = self._update_trial_queue_and_get_next_trial()
#    1339         if next_trial:
#    1340             logger.debug(f"Got new trial to run: {next_trial}")
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in _update_trial_queue_and_get_next_trial(self)
#    1313             # Create pending trials until it fails.
#    1314             while num_pending_trials < self._max_pending_trials:
# -> 1315                 if not self._update_trial_queue(blocking=wait_for_trial):
#    1316                     break
#    1317                 wait_for_trial = False  # wait at most one trial
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in _update_trial_queue(self, blocking, timeout)
#    1066
#    1067         if trial:
# -> 1068             self.add_trial(trial)
#    1069             return True
#    1070
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in add_trial(self, trial)
#     551         # resolve them before adding the trial.
#     552         if self._placeholder_resolvers:
# --> 553             trial.resolve_config_placeholders(self._placeholder_resolvers)
#     554
#     555         # With trial.config resolved, create placement group factory if needed.
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/experiment/trial.py in resolve_config_placeholders(self, placeholder_resolvers)
#     577         # Make a copy of the unresolved config before resolve it.
#     578         self.config = copy.deepcopy(self.__unresolved_config)
# --> 579         resolve_placeholders(self.config, placeholder_resolvers)
#     580
#     581     @property
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/impl/placeholder.py in resolve_placeholders(config, replaced)
#     240
#     241     # RefResolvers first.
# --> 242     __resolve(_RefResolver, args=())
#     243     # Functions need to be resolved after RefResolvers, in case they are
#     244     # referencing values from the RefResolvers.
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/impl/placeholder.py in __resolve(resolver_type, args)
#     234
#     235             for resolver in resolvers:
# --> 236                 if resolver.hash != ph[1]:
#     237                     continue
#     238                 # Found the matching resolver.
#
# TypeError: 'int' object is not subscriptable

# %%
#tuned model object is stored in the variable 'tuned_et'. 
tuned_et
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-56b4ab0ea982> in <cell line: 2>()
#       1 #tuned model object is stored in the variable 'tuned_et'.
# ----> 2 tuned_et
#
# NameError: name 'tuned_et' is not defined

# %% [markdown]
# evaluate Extra Tree

# %%
# !pip install statsmodels --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.9/dist-packages (0.13.5)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels) (23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from statsmodels) (1.22.4)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels) (1.5.4)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.9/dist-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25->statsmodels) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
evaluate_model(tuned_et)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-127-462b45850244> in <cell line: 1>()
# ----> 1 evaluate_model(tuned_et)
#
# NameError: name 'tuned_et' is not defined

# %% [markdown]
# Create Random Forest model

# %%
rf = create_model('rf')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.7692  0.8000  1.0000  0.7692  0.8696  0.0000  0.0000
# 1       0.9231  1.0000  1.0000  0.9091  0.9524  0.7547  0.7785
# 2       0.9231  1.0000  0.9000  1.0000  0.9474  0.8060  0.8216
# 3       0.9167  0.8333  1.0000  0.9000  0.9474  0.7500  0.7746
# 4       0.9167  0.8889  0.8889  1.0000  0.9412  0.8000  0.8165
# 5       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       0.9167  0.7778  1.0000  0.9000  0.9474  0.7500  0.7746
# 7       0.7500  0.7778  0.8889  0.8000  0.8421  0.2500  0.2582
# 8       0.9167  1.0000  0.8889  1.0000  0.9412  0.8000  0.8165
# 9       0.7500  0.5000  0.8889  0.8000  0.8421  0.2500  0.2582
# Mean    0.8782  0.8578  0.9456  0.9078  0.9231  0.6161  0.6299
# SD      0.0834  0.1505  0.0545  0.0875  0.0502  0.3088  0.3131
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 5
# INFO:logs:RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)
# INFO:logs:create_model() succesfully completed......................................

# %% [markdown]
# tune random forest

# %%
tuned_rf = tune_model(rf, search_library='scikit-optimize')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8462  0.8333  1.0000  0.8333  0.9091  0.4348  0.5270
# 1       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 2       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       0.9167  0.9259  1.0000  0.9000  0.9474  0.7500  0.7746
# 4       0.8333  0.8889  0.7778  1.0000  0.8750  0.6364  0.6831
# 5       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       0.9167  0.9259  1.0000  0.9000  0.9474  0.7500  0.7746
# 7       0.8333  0.7778  1.0000  0.8182  0.9000  0.4286  0.5222
# 8       0.9167  1.0000  0.8889  1.0000  0.9412  0.8000  0.8165
# 9       0.7500  0.5185  0.8889  0.8000  0.8421  0.2500  0.2582
# Mean    0.9013  0.8870  0.9556  0.9252  0.9362  0.7050  0.7356
# SD      0.0807  0.1431  0.0737  0.0805  0.0521  0.2521  0.2322
# INFO:logs:create_model_container: 19
# INFO:logs:master_model_container: 19
# INFO:logs:display_container: 6
# INFO:logs:RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=5, max_features=0.9064672106211974,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=1.0050001158033484e-08,
#                        min_impurity_split=None, min_samples_leaf=3,
#                        min_samples_split=6, min_weight_fraction_leaf=0.0,
#                        n_estimators=183, n_jobs=-1, oob_score=False,
#                        random_state=123, verbose=0, warm_start=False)
# INFO:logs:tune_model() succesfully completed......................................

# %% [markdown]
# evaluate random forest model

# %%
evaluate_model(tuned_rf)
# Out:
# INFO:logs:Initializing evaluate_model()
# INFO:logs:evaluate_model(estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=5, max_features=0.9064672106211974,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=1.0050001158033484e-08,
#                        min_impurity_split=None, min_samples_leaf=3,
#                        min_samples_split=6, min_weight_fraction_leaf=0.0,
#                        n_estimators=183, n_jobs=-1, oob_score=False,
#                        random_state=123, verbose=0, warm_start=False), fold=None, fit_kwargs=None, plot_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# Create Gradient Boosting Classifier Model

# %%
gbc = create_model('gbc')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.7692  0.8667  0.9000  0.8182  0.8571  0.2642  0.2725
# 1       0.9231  1.0000  1.0000  0.9091  0.9524  0.7547  0.7785
# 2       0.9231  1.0000  0.9000  1.0000  0.9474  0.8060  0.8216
# 3       0.9167  0.9259  1.0000  0.9000  0.9474  0.7500  0.7746
# 4       0.9167  0.8889  0.8889  1.0000  0.9412  0.8000  0.8165
# 5       0.9167  1.0000  1.0000  0.9000  0.9474  0.7500  0.7746
# 6       0.9167  0.8889  1.0000  0.9000  0.9474  0.7500  0.7746
# 7       0.8333  0.8148  1.0000  0.8182  0.9000  0.4286  0.5222
# 8       0.9167  1.0000  0.8889  1.0000  0.9412  0.8000  0.8165
# 9       0.7500  0.7407  0.8889  0.8000  0.8421  0.2500  0.2582
# Mean    0.8782  0.9126  0.9467  0.9045  0.9223  0.6353  0.6610
# SD      0.0646  0.0855  0.0535  0.0730  0.0391  0.2159  0.2143
# INFO:logs:create_model_container: 20
# INFO:logs:master_model_container: 20
# INFO:logs:display_container: 7
# INFO:logs:GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=123, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
# INFO:logs:create_model() succesfully completed......................................

# %% [markdown]
# Tune Gradient Boosting Classifier Model

# %%
tuned_gbc = tune_model(gbc, search_library='tune-sklearn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-958f2fd8d9b8> in <cell line: 1>()
# ----> 1 tuned_gbc = tune_model(gbc, search_library='tune-sklearn')
#
# /usr/local/lib/python3.9/dist-packages/pycaret/classification.py in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, **kwargs)
#    1099     """
#    1100
# -> 1101     return pycaret.internal.tabular.tune_model_supervised(
#    1102         estimator=estimator,
#    1103         fold=fold,
#
# /usr/local/lib/python3.9/dist-packages/pycaret/internal/tabular.py in tune_model_supervised(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, display, **kwargs)
#    4560                 model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4561         else:
# -> 4562             model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4563         best_params = model_grid.best_params_
#    4564         logger.info(f"best_params: {best_params}")
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_basesearch.py in fit(self, X, y, groups, tune_params, **fit_params)
#     619
#     620         """
# --> 621         return self._fit(X, y, groups, tune_params, **fit_params)
#     622
#     623     def score(self, X, y=None):
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_basesearch.py in _fit(self, X, y, groups, tune_params, **fit_params)
#     530
#     531         self._fill_config_hyperparam(config)
# --> 532         self.analysis_ = self._tune_run(X, y, config, resources_per_trial,
#     533                                         tune_params, fit_params)
#     534
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_search.py in _tune_run(self, X, y, config, resources_per_trial, tune_params, fit_params)
#     820                 "ignore", message="fail_fast='raise' "
#     821                 "detected.")
# --> 822             analysis = tune.run(trainable, **run_args)
#     823         return analysis
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, chdir_to_trial_dir, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, trial_executor, _experiment_checkpoint_dir, _remote, _remote_string_queue, _tuner_api)
#     902                 not runner.is_finished() and not experiment_interrupted_event.is_set()
#     903             ):
# --> 904                 runner.step()
#     905                 if has_verbosity(Verbosity.V1_EXPERIMENT):
#     906                     _report_progress(runner, progress_reporter)
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in step(self)
#    1336             )
#    1337
# -> 1338         next_trial = self._update_trial_queue_and_get_next_trial()
#    1339         if next_trial:
#    1340             logger.debug(f"Got new trial to run: {next_trial}")
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in _update_trial_queue_and_get_next_trial(self)
#    1313             # Create pending trials until it fails.
#    1314             while num_pending_trials < self._max_pending_trials:
# -> 1315                 if not self._update_trial_queue(blocking=wait_for_trial):
#    1316                     break
#    1317                 wait_for_trial = False  # wait at most one trial
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in _update_trial_queue(self, blocking, timeout)
#    1066
#    1067         if trial:
# -> 1068             self.add_trial(trial)
#    1069             return True
#    1070
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in add_trial(self, trial)
#     551         # resolve them before adding the trial.
#     552         if self._placeholder_resolvers:
# --> 553             trial.resolve_config_placeholders(self._placeholder_resolvers)
#     554
#     555         # With trial.config resolved, create placement group factory if needed.
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/experiment/trial.py in resolve_config_placeholders(self, placeholder_resolvers)
#     577         # Make a copy of the unresolved config before resolve it.
#     578         self.config = copy.deepcopy(self.__unresolved_config)
# --> 579         resolve_placeholders(self.config, placeholder_resolvers)
#     580
#     581     @property
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/impl/placeholder.py in resolve_placeholders(config, replaced)
#     240
#     241     # RefResolvers first.
# --> 242     __resolve(_RefResolver, args=())
#     243     # Functions need to be resolved after RefResolvers, in case they are
#     244     # referencing values from the RefResolvers.
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/impl/placeholder.py in __resolve(resolver_type, args)
#     234
#     235             for resolver in resolvers:
# --> 236                 if resolver.hash != ph[1]:
#     237                     continue
#     238                 # Found the matching resolver.
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# Evaluate Gradient Boosting Classifier Model

# %%
evaluate_model(tuned_gbc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-a180e814f64e> in <cell line: 1>()
# ----> 1 evaluate_model(tuned_gbc)
#
# NameError: name 'tuned_gbc' is not defined

# %% [markdown]
# Tune Best model

# %%
# Tune hyperparameters with scikit-learn(default)
tuned_best_model = tune_model(best_model, search_library='tune-sklearn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-54518a1a3e2c> in <cell line: 2>()
#       1 # Tune hyperparameters with scikit-learn(default)
# ----> 2 tuned_best_model = tune_model(best_model, search_library='tune-sklearn')
#
# /usr/local/lib/python3.9/dist-packages/pycaret/classification.py in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, **kwargs)
#    1099     """
#    1100
# -> 1101     return pycaret.internal.tabular.tune_model_supervised(
#    1102         estimator=estimator,
#    1103         fold=fold,
#
# /usr/local/lib/python3.9/dist-packages/pycaret/internal/tabular.py in tune_model_supervised(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, display, **kwargs)
#    4560                 model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4561         else:
# -> 4562             model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4563         best_params = model_grid.best_params_
#    4564         logger.info(f"best_params: {best_params}")
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_basesearch.py in fit(self, X, y, groups, tune_params, **fit_params)
#     619
#     620         """
# --> 621         return self._fit(X, y, groups, tune_params, **fit_params)
#     622
#     623     def score(self, X, y=None):
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_basesearch.py in _fit(self, X, y, groups, tune_params, **fit_params)
#     530
#     531         self._fill_config_hyperparam(config)
# --> 532         self.analysis_ = self._tune_run(X, y, config, resources_per_trial,
#     533                                         tune_params, fit_params)
#     534
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_search.py in _tune_run(self, X, y, config, resources_per_trial, tune_params, fit_params)
#     820                 "ignore", message="fail_fast='raise' "
#     821                 "detected.")
# --> 822             analysis = tune.run(trainable, **run_args)
#     823         return analysis
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, chdir_to_trial_dir, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, trial_executor, _experiment_checkpoint_dir, _remote, _remote_string_queue, _tuner_api)
#     902                 not runner.is_finished() and not experiment_interrupted_event.is_set()
#     903             ):
# --> 904                 runner.step()
#     905                 if has_verbosity(Verbosity.V1_EXPERIMENT):
#     906                     _report_progress(runner, progress_reporter)
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in step(self)
#    1336             )
#    1337
# -> 1338         next_trial = self._update_trial_queue_and_get_next_trial()
#    1339         if next_trial:
#    1340             logger.debug(f"Got new trial to run: {next_trial}")
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in _update_trial_queue_and_get_next_trial(self)
#    1313             # Create pending trials until it fails.
#    1314             while num_pending_trials < self._max_pending_trials:
# -> 1315                 if not self._update_trial_queue(blocking=wait_for_trial):
#    1316                     break
#    1317                 wait_for_trial = False  # wait at most one trial
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in _update_trial_queue(self, blocking, timeout)
#    1066
#    1067         if trial:
# -> 1068             self.add_trial(trial)
#    1069             return True
#    1070
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in add_trial(self, trial)
#     551         # resolve them before adding the trial.
#     552         if self._placeholder_resolvers:
# --> 553             trial.resolve_config_placeholders(self._placeholder_resolvers)
#     554
#     555         # With trial.config resolved, create placement group factory if needed.
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/experiment/trial.py in resolve_config_placeholders(self, placeholder_resolvers)
#     577         # Make a copy of the unresolved config before resolve it.
#     578         self.config = copy.deepcopy(self.__unresolved_config)
# --> 579         resolve_placeholders(self.config, placeholder_resolvers)
#     580
#     581     @property
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/impl/placeholder.py in resolve_placeholders(config, replaced)
#     240
#     241     # RefResolvers first.
# --> 242     __resolve(_RefResolver, args=())
#     243     # Functions need to be resolved after RefResolvers, in case they are
#     244     # referencing values from the RefResolvers.
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/impl/placeholder.py in __resolve(resolver_type, args)
#     234
#     235             for resolver in resolvers:
# --> 236                 if resolver.hash != ph[1]:
#     237                     continue
#     238                 # Found the matching resolver.
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# tuned_best_model

# %%
tuned_best_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-afd4daa0f0a5> in <cell line: 1>()
# ----> 1 tuned_best_model
#
# NameError: name 'tuned_best_model' is not defined

# %% [markdown]
# Evaluate the Best Model

# %%
evaluate_model(tuned_best_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-41d88cb8d9b0> in <cell line: 1>()
# ----> 1 evaluate_model(tuned_best_model)
#
# NameError: name 'tuned_best_model' is not defined

# %% [markdown]
# Classification+PCA

# %%
clf_pca = setup(data=data, target='status', train_size=0.7, session_id=123, normalize = True, pca = True, pca_components = 3)
# Out:
#                                Description             Value
# 0                               session_id               123
# 1                                   Target            status
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data          (176, 8)
# 5                           Missing Values             False
# 6                         Numeric Features                 7
# 7                     Categorical Features                 0
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set          (123, 3)
# 12                    Transformed Test Set           (53, 3)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              a0cf
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize              True
# 30                        Normalize Method            zscore
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA              True
# 34                              PCA Method            linear
# 35                          PCA Components                 3
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE
# INFO:logs:create_model_container: 0
# INFO:logs:master_model_container: 0
# INFO:logs:display_container: 1
# INFO:logs:Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='status',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strat...
#                 ('dummy', Dummify(target='status')),
#                 ('fix_perfect', Remove_100(target='status')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'),
#                 ('pca',
#                  Reduce_Dimensions_For_Supervised_Path(method='pca_liner',
#                                                        random_state=123,
#                                                        target='status',
#                                                        variance_retained_or_number_of_components=None))],
#          verbose=False)
# INFO:logs:setup() succesfully completed......................................

# %%
best_model_pca1, best_model_pca2, best_model_pca3 = compare_models(n_select=3)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# knn                K Neighbors Classifier    0.8769  0.8850  0.9233  0.9175
# et                 Extra Trees Classifier    0.8769  0.9052  0.9444  0.9022
# lightgbm  Light Gradient Boosting Machine    0.8699  0.8200  0.9356  0.9047
# rf               Random Forest Classifier    0.8692  0.8454  0.9456  0.8954
# xgboost         Extreme Gradient Boosting    0.8545  0.8452  0.9156  0.9047
# gbc          Gradient Boosting Classifier    0.8365  0.8415  0.9022  0.8929
# dt               Decision Tree Classifier    0.8199  0.7567  0.8800  0.8889
# ridge                    Ridge Classifier    0.8045  0.0000  0.9456  0.8277
# ada                  Ada Boost Classifier    0.7942  0.8081  0.8789  0.8582
# lda          Linear Discriminant Analysis    0.7891  0.8107  0.9256  0.8257
# lr                    Logistic Regression    0.7795  0.8196  0.9122  0.8222
# dummy                    Dummy Classifier    0.7558  0.5000  1.0000  0.7558
# nb                            Naive Bayes    0.7481  0.8233  0.7633  0.8946
# svm                   SVM - Linear Kernel    0.7237  0.0000  0.8311  0.8285
# qda       Quadratic Discriminant Analysis    0.7147  0.8230  0.7289  0.8849
#
#               F1   Kappa     MCC  TT (Sec)
# knn       0.9183  0.6607  0.6789     0.019
# et        0.9208  0.6261  0.6327     0.305
# lightgbm  0.9174  0.5973  0.6045     0.231
# rf        0.9173  0.5901  0.6043     0.197
# xgboost   0.9057  0.5658  0.5788     0.084
# gbc       0.8938  0.5157  0.5315     0.133
# dt        0.8810  0.4876  0.4954     0.014
# ridge     0.8794  0.3416  0.3703     0.014
# ada       0.8649  0.4051  0.4111     0.176
# lda       0.8690  0.3092  0.3366     0.022
# lr        0.8611  0.2928  0.3032     0.908
# dummy     0.8609  0.0000  0.0000     0.019
# nb        0.8191  0.3928  0.4147     0.016
# svm       0.8101  0.1969  0.2227     0.015
# qda       0.7929  0.3180  0.3448     0.014
# INFO:logs:create_model_container: 15
# INFO:logs:master_model_container: 15
# INFO:logs:display_container: 2
# INFO:logs:[KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform'), ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False), LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)]
# INFO:logs:compare_models() succesfully completed......................................

# %%
best_model_pca1
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# tune best model1

# %%
# Tune hyperparameters with scikit-learn (default)
tuned_best_model_pca1 = tune_model(best_model_pca1)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8462  0.7667  1.0000  0.8333  0.9091  0.4348  0.5270
# 1       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 2       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       0.9167  0.9259  0.8889  1.0000  0.9412  0.8000  0.8165
# 4       0.9167  0.9259  0.8889  1.0000  0.9412  0.8000  0.8165
# 5       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       0.8333  0.7778  0.8889  0.8889  0.8889  0.5556  0.5556
# 7       0.9167  0.8148  1.0000  0.9000  0.9474  0.7500  0.7746
# 8       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 9       0.8333  0.7037  0.8889  0.8889  0.8889  0.5556  0.5556
# Mean    0.9263  0.8915  0.9556  0.9511  0.9517  0.7896  0.8046
# SD      0.0676  0.1091  0.0544  0.0621  0.0439  0.2035  0.1884
# INFO:logs:create_model_container: 16
# INFO:logs:master_model_container: 16
# INFO:logs:display_container: 3
# INFO:logs:KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=-1, n_neighbors=12, p=2,
#                      weights='distance')
# INFO:logs:tune_model() succesfully completed......................................

# %%
tuned_best_model_pca1
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=-1, n_neighbors=12, p=2,
#                      weights='distance')

# %% [markdown]
# evaluate best model1

# %%
evaluate_model(tuned_best_model_pca1)
# Out:
# INFO:logs:Initializing evaluate_model()
# INFO:logs:evaluate_model(estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=-1, n_neighbors=12, p=2,
#                      weights='distance'), fold=None, fit_kwargs=None, plot_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# tune best model2

# %%
tuned_best_model_pca2 = tune_model(best_model_pca2, search_library='scikit-optimize')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8462  0.8000  1.0000  0.8333  0.9091  0.4348  0.5270
# 1       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 2       0.9231  1.0000  0.9000  1.0000  0.9474  0.8060  0.8216
# 3       0.9167  0.9630  0.8889  1.0000  0.9412  0.8000  0.8165
# 4       0.9167  0.8889  0.8889  1.0000  0.9412  0.8000  0.8165
# 5       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       0.8333  0.7407  0.8889  0.8889  0.8889  0.5556  0.5556
# 7       0.8333  0.8148  0.8889  0.8889  0.8889  0.5556  0.5556
# 8       0.9167  1.0000  0.8889  1.0000  0.9412  0.8000  0.8165
# 9       0.7500  0.7407  0.7778  0.8750  0.8235  0.4000  0.4082
# Mean    0.8936  0.8948  0.9122  0.9486  0.9281  0.7152  0.7317
# SD      0.0743  0.1057  0.0664  0.0646  0.0506  0.2052  0.1955
# INFO:logs:create_model_container: 17
# INFO:logs:master_model_container: 17
# INFO:logs:display_container: 4
# INFO:logs:ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                      class_weight='balanced_subsample', criterion='entropy',
#                      max_depth=8, max_features=0.6877870002297917,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=9.601039817035328e-06,
#                      min_impurity_split=None, min_samples_leaf=2,
#                      min_samples_split=6, min_weight_fraction_leaf=0.0,
#                      n_estimators=76, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False)
# INFO:logs:tune_model() succesfully completed......................................

# %% [markdown]
# evaluate best model2

# %%
evaluate_model(tuned_best_model_pca2)
# Out:
# INFO:logs:Initializing evaluate_model()
# INFO:logs:evaluate_model(estimator=ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                      class_weight='balanced_subsample', criterion='entropy',
#                      max_depth=8, max_features=0.6877870002297917,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=9.601039817035328e-06,
#                      min_impurity_split=None, min_samples_leaf=2,
#                      min_samples_split=6, min_weight_fraction_leaf=0.0,
#                      n_estimators=76, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False), fold=None, fit_kwargs=None, plot_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# tune best model3

# %%
tuned_best_model_pca3 = tune_model(best_model_pca3, search_library='tune-sklearn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-c65a8187f9ab> in <cell line: 1>()
# ----> 1 tuned_best_model_pca3 = tune_model(best_model_pca3, search_library='tune-sklearn')
#
# /usr/local/lib/python3.9/dist-packages/pycaret/classification.py in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, **kwargs)
#    1099     """
#    1100
# -> 1101     return pycaret.internal.tabular.tune_model_supervised(
#    1102         estimator=estimator,
#    1103         fold=fold,
#
# /usr/local/lib/python3.9/dist-packages/pycaret/internal/tabular.py in tune_model_supervised(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, display, **kwargs)
#    4560                 model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4561         else:
# -> 4562             model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4563         best_params = model_grid.best_params_
#    4564         logger.info(f"best_params: {best_params}")
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_basesearch.py in fit(self, X, y, groups, tune_params, **fit_params)
#     619
#     620         """
# --> 621         return self._fit(X, y, groups, tune_params, **fit_params)
#     622
#     623     def score(self, X, y=None):
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_basesearch.py in _fit(self, X, y, groups, tune_params, **fit_params)
#     530
#     531         self._fill_config_hyperparam(config)
# --> 532         self.analysis_ = self._tune_run(X, y, config, resources_per_trial,
#     533                                         tune_params, fit_params)
#     534
#
# /usr/local/lib/python3.9/dist-packages/tune_sklearn/tune_search.py in _tune_run(self, X, y, config, resources_per_trial, tune_params, fit_params)
#     820                 "ignore", message="fail_fast='raise' "
#     821                 "detected.")
# --> 822             analysis = tune.run(trainable, **run_args)
#     823         return analysis
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, chdir_to_trial_dir, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, trial_executor, _experiment_checkpoint_dir, _remote, _remote_string_queue, _tuner_api)
#     902                 not runner.is_finished() and not experiment_interrupted_event.is_set()
#     903             ):
# --> 904                 runner.step()
#     905                 if has_verbosity(Verbosity.V1_EXPERIMENT):
#     906                     _report_progress(runner, progress_reporter)
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in step(self)
#    1336             )
#    1337
# -> 1338         next_trial = self._update_trial_queue_and_get_next_trial()
#    1339         if next_trial:
#    1340             logger.debug(f"Got new trial to run: {next_trial}")
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in _update_trial_queue_and_get_next_trial(self)
#    1313             # Create pending trials until it fails.
#    1314             while num_pending_trials < self._max_pending_trials:
# -> 1315                 if not self._update_trial_queue(blocking=wait_for_trial):
#    1316                     break
#    1317                 wait_for_trial = False  # wait at most one trial
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in _update_trial_queue(self, blocking, timeout)
#    1066
#    1067         if trial:
# -> 1068             self.add_trial(trial)
#    1069             return True
#    1070
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/execution/trial_runner.py in add_trial(self, trial)
#     551         # resolve them before adding the trial.
#     552         if self._placeholder_resolvers:
# --> 553             trial.resolve_config_placeholders(self._placeholder_resolvers)
#     554
#     555         # With trial.config resolved, create placement group factory if needed.
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/experiment/trial.py in resolve_config_placeholders(self, placeholder_resolvers)
#     577         # Make a copy of the unresolved config before resolve it.
#     578         self.config = copy.deepcopy(self.__unresolved_config)
# --> 579         resolve_placeholders(self.config, placeholder_resolvers)
#     580
#     581     @property
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/impl/placeholder.py in resolve_placeholders(config, replaced)
#     240
#     241     # RefResolvers first.
# --> 242     __resolve(_RefResolver, args=())
#     243     # Functions need to be resolved after RefResolvers, in case they are
#     244     # referencing values from the RefResolvers.
#
# /usr/local/lib/python3.9/dist-packages/ray/tune/impl/placeholder.py in __resolve(resolver_type, args)
#     234
#     235             for resolver in resolvers:
# --> 236                 if resolver.hash != ph[1]:
#     237                     continue
#     238                 # Found the matching resolver.
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# evaluate best model3

# %%
evaluate_model(tuned_best_model_pca3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-c3877ba15b2e> in <cell line: 1>()
# ----> 1 evaluate_model(tuned_best_model_pca3)
#
# NameError: name 'tuned_best_model_pca3' is not defined

# %% [markdown]
# Explainable AI with shaply values

# %%
# !pip install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from shap) (1.5.4)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.9/dist-packages (from shap) (23.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from shap) (0.23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from shap) (1.22.4)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.9/dist-packages (from shap) (4.64.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from shap) (2.2.1)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
print("Numpy version: ", np.__version__)
# Out:
# Numpy version:  1.22.4

# %%
# !pip install numba==0.53
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting numba==0.53
#   Downloading numba-0.53.0-cp39-cp39-manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 31.3 MB/s eta 0:00:00
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading llvmlite-0.36.0-cp39-cp39-manylinux2010_x86_64.whl (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 46.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.9/dist-packages (from numba==0.53) (1.22.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba==0.53) (67.7.2)
# Installing collected packages: llvmlite, numba
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.4
#     Uninstalling numba-0.56.4:
#       Successfully uninstalled numba-0.56.4
# Successfully installed llvmlite-0.36.0 numba-0.53.0

# %%
import shap

# %%
et_pca = create_model('et')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.7692  0.8667  1.0000  0.7692  0.8696  0.0000  0.0000
# 1       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 2       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       0.9167  0.9630  1.0000  0.9000  0.9474  0.7500  0.7746
# 4       0.8333  0.8889  0.8889  0.8889  0.8889  0.5556  0.5556
# 5       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       0.8333  0.6852  0.8889  0.8889  0.8889  0.5556  0.5556
# 7       0.7500  0.8519  0.8889  0.8000  0.8421  0.2500  0.2582
# 8       0.9167  1.0000  1.0000  0.9000  0.9474  0.7500  0.7746
# 9       0.7500  0.7963  0.7778  0.8750  0.8235  0.4000  0.4082
# Mean    0.8769  0.9052  0.9444  0.9022  0.9208  0.6261  0.6327
# SD      0.0981  0.1021  0.0745  0.0761  0.0637  0.3232  0.3237
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 5
# INFO:logs:ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)
# INFO:logs:create_model() succesfully completed......................................

# %%
tuned_et_pca = tune_model(et_pca, search_library = 'scikit-optimize')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8462  0.8000  1.0000  0.8333  0.9091  0.4348  0.5270
# 1       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 2       0.9231  1.0000  0.9000  1.0000  0.9474  0.8060  0.8216
# 3       0.9167  0.9630  0.8889  1.0000  0.9412  0.8000  0.8165
# 4       0.9167  0.8889  0.8889  1.0000  0.9412  0.8000  0.8165
# 5       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       0.8333  0.7407  0.8889  0.8889  0.8889  0.5556  0.5556
# 7       0.8333  0.8148  0.8889  0.8889  0.8889  0.5556  0.5556
# 8       0.9167  1.0000  0.8889  1.0000  0.9412  0.8000  0.8165
# 9       0.7500  0.7407  0.7778  0.8750  0.8235  0.4000  0.4082
# Mean    0.8936  0.8948  0.9122  0.9486  0.9281  0.7152  0.7317
# SD      0.0743  0.1057  0.0664  0.0646  0.0506  0.2052  0.1955
# INFO:logs:create_model_container: 19
# INFO:logs:master_model_container: 19
# INFO:logs:display_container: 6
# INFO:logs:ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                      class_weight='balanced_subsample', criterion='entropy',
#                      max_depth=8, max_features=0.6877870002297917,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=9.601039817035328e-06,
#                      min_impurity_split=None, min_samples_leaf=2,
#                      min_samples_split=6, min_weight_fraction_leaf=0.0,
#                      n_estimators=76, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False)
# INFO:logs:tune_model() succesfully completed......................................

# %% [markdown]
# SHAP Summary Plot

# %%
interpret_model(tuned_et_pca, plot='summary')
# Out:
# INFO:logs:Initializing interpret_model()
# INFO:logs:interpret_model(estimator=ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                      class_weight='balanced_subsample', criterion='entropy',
#                      max_depth=8, max_features=0.6877870002297917,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=9.601039817035328e-06,
#                      min_impurity_split=None, min_samples_leaf=2,
#                      min_samples_split=6, min_weight_fraction_leaf=0.0,
#                      n_estimators=76, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False), use_train_data=False, X_new_sample=None, y_new_sample=None, feature=None, kwargs={}, observation=None, plot=summary, save=False)
# INFO:logs:Checking exceptions
# INFO:logs:plot type: summary
# INFO:logs:Creating TreeExplainer
# INFO:logs:Compiling shap values
# INFO:logs:Visual Rendered Successfully
# INFO:logs:interpret_model() succesfully completed......................................

# %% [markdown]
# Visualize a single prediction

# %%
interpret_model(tuned_et_pca, plot='reason', observation=1)
# Out:
# INFO:logs:Initializing interpret_model()
# INFO:logs:interpret_model(estimator=ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                      class_weight='balanced_subsample', criterion='entropy',
#                      max_depth=8, max_features=0.6877870002297917,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=9.601039817035328e-06,
#                      min_impurity_split=None, min_samples_leaf=2,
#                      min_samples_split=6, min_weight_fraction_leaf=0.0,
#                      n_estimators=76, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False), use_train_data=False, X_new_sample=None, y_new_sample=None, feature=None, kwargs={}, observation=1, plot=reason, save=False)
# INFO:logs:Checking exceptions
# INFO:logs:plot type: reason
# INFO:logs:model type detected: type 1
# INFO:logs:Creating TreeExplainer
# INFO:logs:Compiling shap values
# INFO:logs:model type detected: Unknown
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# INFO:logs:Visual Rendered Successfully
# INFO:logs:interpret_model() succesfully completed......................................
# <div id='iDRF0RGCY89VVDKIV9VPK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5000000000000006, "outValue": 0.6512732972361932, "link": "identity", "featureNames": ["Component_1", "Component_2", "Component_3"], "features": {"0": {"effect": 0.06908901486445747, "value": -0.575071394443512}, "1": {"effect": 0.13229077970545078, "value": -0.8612186908721924}, "2": {"effect": -0.05010649733371557, "value": -0.3926678001880646}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iDRF0RGCY89VVDKIV9VPK')
#   );
# </script>

# %% [markdown]
# Visualize many predictions

# %%
interpret_model(tuned_et_pca, plot='reason')
# Out:
# INFO:logs:Initializing interpret_model()
# INFO:logs:interpret_model(estimator=ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                      class_weight='balanced_subsample', criterion='entropy',
#                      max_depth=8, max_features=0.6877870002297917,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=9.601039817035328e-06,
#                      min_impurity_split=None, min_samples_leaf=2,
#                      min_samples_split=6, min_weight_fraction_leaf=0.0,
#                      n_estimators=76, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False), use_train_data=False, X_new_sample=None, y_new_sample=None, feature=None, kwargs={}, observation=None, plot=reason, save=False)
# INFO:logs:Checking exceptions
# INFO:logs:plot type: reason
# INFO:logs:model type detected: type 1
# INFO:logs:Creating TreeExplainer
# INFO:logs:Compiling shap values
# WARNING:logs:Observation set to None. Model agnostic plot will be rendered.
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# INFO:logs:Visual Rendered Successfully
# INFO:logs:interpret_model() succesfully completed......................................
# <div id='iA1FYEAU2GCFJIBS14Q4C'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5000000000000006, "link": "identity", "featureNames": ["Component_1", "Component_2", "Component_3"], "explanations": [{"outValue": 0.5086132638160792, "simIndex": 12.0, "features": {"0": {"effect": 0.077388753048635, "value": -0.20750398933887482}, "1": {"effect": -0.029433117389265878, "value": -0.30456405878067017}, "2": {"effect": -0.03934237184329055, "value": -0.3609117567539215}}}, {"outValue": 0.6512732972361932, "simIndex": 23.0, "features": {"0": {"effect": 0.06908901486445747, "value": -0.575071394443512}, "1": {"effect": 0.13229077970545078, "value": -0.8612186908721924}, "2": {"effect": -0.05010649733371557, "value": -0.3926678001880646}}}, {"outValue": 0.6227550526479915, "simIndex": 21.0, "features": {"0": {"effect": 0.07505411385975332, "value": -0.3918057680130005}, "1": {"effect": 0.10257044868695096, "value": -0.8001465797424316}, "2": {"effect": -0.054869509898713316, "value": -0.30863791704177856}}}, {"outValue": 0.645860975058889, "simIndex": 9.0, "features": {"0": {"effect": 0.1873069125904522, "value": 0.4980818033218384}, "1": {"effect": 0.008959211136182183, "value": -0.5770708322525024}, "2": {"effect": -0.05040514866774595, "value": -0.3924791216850281}}}, {"outValue": 0.8717766158611551, "simIndex": 24.0, "features": {"0": {"effect": 0.14411467858063448, "value": 0.6974813938140869}, "1": {"effect": 0.19426186191758382, "value": 0.7204900979995728}, "2": {"effect": 0.033400075362936175, "value": 0.31342217326164246}}}, {"outValue": 0.31919478674507795, "simIndex": 45.0, "features": {"0": {"effect": -0.17396385877484064, "value": -1.2412514686584473}, "1": {"effect": -0.005264529058920533, "value": -0.2163427621126175}, "2": {"effect": -0.0015768254211614573, "value": -0.23639649152755737}}}, {"outValue": 0.8431587816075952, "simIndex": 41.0, "features": {"0": {"effect": 0.32548630776374965, "value": 1.4000201225280762}, "1": {"effect": 0.030904867276185344, "value": -0.1264444887638092}, "2": {"effect": -0.013232393432340448, "value": -0.4471765160560608}}}, {"outValue": 0.6354263296555287, "simIndex": 15.0, "features": {"0": {"effect": 0.09266317319576223, "value": -0.18962787091732025}, "1": {"effect": -0.009830840866664485, "value": -0.41005727648735046}, "2": {"effect": 0.05259399732643034, "value": -0.5831815004348755}}}, {"outValue": 0.8144675950043821, "simIndex": 40.0, "features": {"0": {"effect": 0.25599462600824735, "value": 0.9859839081764221}, "1": {"effect": 0.04500877751947904, "value": -0.6042072176933289}, "2": {"effect": 0.013464191476655254, "value": -0.5829983353614807}}}, {"outValue": 0.49908691844503644, "simIndex": 42.0, "features": {"0": {"effect": -0.029624449571058007, "value": -0.9857827425003052}, "1": {"effect": -0.04332145983243532, "value": -0.3068545162677765}, "2": {"effect": 0.07203282784852923, "value": -0.7455018758773804}}}, {"outValue": 0.8804839993103477, "simIndex": 38.0, "features": {"0": {"effect": 0.28859577178264606, "value": 1.724831461906433}, "1": {"effect": 0.025859955182587463, "value": -0.19222693145275116}, "2": {"effect": 0.06602827234511359, "value": -0.8292497992515564}}}, {"outValue": 0.561367417461919, "simIndex": 13.0, "features": {"0": {"effect": 0.06477115800836661, "value": -0.36928096413612366}, "1": {"effect": -0.008061773618590931, "value": -0.24092918634414673}, "2": {"effect": 0.004658033072142714, "value": -0.12443115562200546}}}, {"outValue": 0.6869462940177029, "simIndex": 19.0, "features": {"0": {"effect": 0.07424788569863744, "value": -0.5158804655075073}, "1": {"effect": 0.09563370825530658, "value": -0.7342256903648376}, "2": {"effect": 0.017064700063758327, "value": -0.5061445832252502}}}, {"outValue": 0.6033916576238316, "simIndex": 14.0, "features": {"0": {"effect": 0.09176276596744608, "value": -0.14587175846099854}, "1": {"effect": 0.02272650246988844, "value": -0.67021644115448}, "2": {"effect": -0.011097610813503479, "valu ...
