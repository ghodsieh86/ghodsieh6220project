# %% [markdown]
# <a href="https://colab.research.google.com/github/ghodsieh86/ghodsieh6220project/blob/main/mainta%20proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import python modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
# use seaborn plotting style defaults
import seaborn as sns; sns.set()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# upload file

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/maint.csv')

print(df.head())
# Out:
#       X1     X2    X3    X4  X5  Target
# 0  298.1  308.6  1551  42.8   0       0
# 1  298.2  308.7  1408  46.3   3       0
# 2  298.1  308.5  1498  49.4   5       0
# 3  298.2  308.6  1433  39.5   7       0
# 4  298.2  308.7  1408  40.0   9       0

# %%
len(df.index)
# Out:
# 10000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      10000 non-null  float64
#  1   X2      10000 non-null  float64
#  2   X3      10000 non-null  int64
#  3   X4      10000 non-null  float64
#  4   X5      10000 non-null  int64
#  5   Target  10000 non-null  int64
# dtypes: float64(3), int64(3)
# memory usage: 468.9 KB

# %%
print("Number of duplicated rows is: ", df.duplicated().sum())
# Out:
# Number of duplicated rows is:  0

# %%
print("Number of rows with NaNs is: ", df.isna().any(axis=1).sum())
# Out:
# Number of rows with NaNs is:  0

# %% [markdown]
# explatory data analysis

# %%
sns.pairplot(df, hue='Target')
plt.show()

# %%
y =df['Target']
y.value_counts().plot(kind='pie')
plt.ylabel('')
plt.show()

# %%
#m,n=df.shape #size of data
#X = df.ix[:,0:n].values # Feature matrix
#from sklearn.preprocessing import StandardScaler
#X = StandardScaler().fit_transform(X) #normalize data

# %%
#normalize data
df = (df - df.mean())/df.std()
# Displaying DataFrame columns.
df.columns
# Some basic information about each column in the DataFrame 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      10000 non-null  float64
#  1   X2      10000 non-null  float64
#  2   X3      10000 non-null  float64
#  3   X4      10000 non-null  float64
#  4   X5      10000 non-null  float64
# dtypes: float64(5)
# memory usage: 390.8 KB

# %% [markdown]
# observation and variable

# %%
observations = list(df.index)
variables = list(df.columns)

# %%
sns.boxplot(data=df, orient="v", palette="Set2")
# Out:
# <AxesSubplot:>

# %%
#pairplot
sns.pairplot(df)

# %% [markdown]
# covariance

# %%
dfc = df - df.mean() #centered data
plt. figure()
ax = sns.heatmap(dfc.cov(), cmap='RdYlGn_r', linewidths=0.5, annot=True, 
            cbar=False, square=True)
plt.yticks(rotation=0)
ax.tick_params(labelbottom=False,labeltop=True)
plt.title('Covariance matrix')
# Out:
# Text(0.5, 1.0, 'Covariance matrix')

# %% [markdown]
# PCA

# %% [markdown]
# eigenvectors

# %%
X = np.array([23, 4, 29, 44, 47, 24, 40, 23, 23, 44, 33, 27, 60, 46, 61, 11, 23, 62, 31, 44, 77, 14, 65, 42])
#X = np.array([99, 85, 86, 71, 82, 95, 108, 87, 89, 89, 78, 86])
#X = np.array([12, 12, 12, 14, 15, 16, 16, 16, 16, 17, 17, 18, 18, 18, 19, 19, 20, 20, 20, 20, 
#              20, 20, 20, 20, 21, 21, 21, 22, 22, 23, 23, 23, 24, 24, 25, 26, 26, 28, 28, 28])			  
#X = np.random.poisson(35, 15)

# %%
A = pca.components_.T 
plt. figure()
plt.scatter(A[:,0],A[:,1],c='r')
plt.xlabel('
')
plt.ylabel('
');
for label, x, y in zip(variables, A[:, 0], A[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(-2, 2),
        textcoords='offset points', ha='right', va='bottom')
# Out:
#   File "<ipython-input-26-69e4d1bd3ae2>", line 4
#     plt.xlabel('
#                 ^
# SyntaxError: EOL while scanning string literal
